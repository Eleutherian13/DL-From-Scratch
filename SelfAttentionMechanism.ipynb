# %% [markdown]
# ### part 4 : self attention mechanism
# the heart of transformer architecture

# %%
print("hi there ")
# Out:
# hi there

# %%
# we will implement the self attention mechanism from scratch on a toy sample 
import numpy as np




sentence = ["The" , "cat" , "sat" , "on" , "the" , "mat"]

# for simplicity we will use the small dimention of the embedding matrix
d_model = 8     # embedding dimention 
d_k = 4         # key / query dimention
d_v = 4         # value dimention


# random embedding for our words (pretend these are meaningfull weights)
np.random.seed(42)
embedding = {
    "The":np.random.rand(d_model) ,
    "cat": np.random.rand(d_model) ,
    "sat" : np.random.rand(d_model),
    "on"  : np.random.rand(d_model),
    "the" : np.random.rand(d_model),
    "mat" : np.random.rand(d_model)
}

# stack into a matrix : (seq lenght , d_model)
x = np.array([embedding[word] for word in sentence])
print(f"input shape : {X.shape} (3 words , {d_model} dimention)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 28
#      26 # stack into a matrix : (seq lenght , d_model)
#      27 x = np.array([embedding[word] for word in sentence])
# ---> 28 print(f"input shape : {X.shape} (3 words , {d_model} dimention)")
#
# NameError: name 'X' is not defined
