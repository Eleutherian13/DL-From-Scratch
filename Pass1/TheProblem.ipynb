# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 

print("hi there ")
# Out:
# hi there

# %%
df = pd.read_csv("./placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
print(df.shape)
df.head()
# Out:
# (100, 3)
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(x = df['cgpa'],y= df['resume_score'],hue=df['placed'] , s = 100)
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[: , 0:2]
y = df.iloc[: , -1]

# %%
from sklearn.linear_model import Perceptron 
p = Perceptron()

# %%
p.fit(X , y )
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# Out:
# array([-25.])

# %%
# !pip install mlxtend
from mlxtend.plotting import plot_decision_regions
# Out:
# Collecting mlxtend
#   Using cached mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from mlxtend) (2.3.5)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\manas\onedrive\desktop\dl campusx\.venv\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Using cached mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values , y.values , clf = p , legend = 2)
# Out:
# c:\Users\manas\OneDrive\Desktop\DL CampusX\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
pd.read_csv('./placement.csv')
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]
